# %%
import sys
sys.path.insert(0, '/private/groups/brookslab/gabai/tools/NEMO/src/')
from plotUtil import *
import matplotlib as mpl
mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['font.size'] = 12

# %%
gtfFile = '../data/ref/Saccharomyces_cerevisiae.R64-1-1.109.gtf'

# %% [markdown]
# ### Download prediction data from : https://public.gi.ucsc.edu/brookslab/addseq/

# %% [markdown]
# ### PanelA CLN2 promoter

# %%
cln2_pred  = '../data/resnetv1_chrXVI_all_prediction.tsv'
region = 'chrXVI:66000-67600'
pregion = 'chrXVI:66400-67550'
step = 20
chrom = region.split(':')[0]
qstart, qend = int(region.split(':')[1].split('-')[0]), int(region.split(':')[1].split('-')[1])
bins = np.arange(qstart, qend, step)

# %%
plotAllTrack(cln2_pred, gtfFile, outpath = '../figures/', 
             prefix ='Figure3A_resnetv1_CLN2_3_clusters_seed42_step20', bins = bins, region = region, seed=42,
             pregion = pregion, method = '', step=20, vlines = '', xticks_space =100,
             ncluster = 3, savefig = True, trackHeight = 0.8, colorRange=(0.3, 0.55, 0.6), fig_size=(6,4), track_ylim_adjust=10)
# Out:
# Start clustering reads...
# preprocessing input matrix...
# number of reads before filtering: 54
# number of reads kept: 45
# writing output to file:  ../figures/Figure3A_resnetv1_CLN2_3_clusters_seed42_step20_chrXVI:66400-67550.mtx
# Clustering with number of clusters = 3
# Finished clustering reads!
# Figure size: 6 4
# plotting gene annotations...

# %% [markdown]
# ### PanelB NUP170 gene

# %%
YBL079W_pred  = '../data/resnetv1_chrII_all_prediction.tsv'
region = 'chrII:74300-75900'
pregion = 'chrII:74300-75900'
step = 20
chrom = region.split(':')[0]
qstart, qend = int(region.split(':')[1].split('-')[0]), int(region.split(':')[1].split('-')[1])
bins = np.arange(qstart, qend, step)

# %%
plotAllTrack(YBL079W_pred, gtfFile, outpath = '../figures/', 
             step=20,
             prefix ='Figure3B_NUP170_auto_clusters_seed42_step20_na0.8', bins = bins, region = region, seed=42,
             pregion = pregion, method = '', vlines = '', na_thred=0.2, ncluster='',
             savefig = True, trackHeight = 0.3, fig_size=(6,5), track_agg_adjust=0.1,
             xticks_space =100, subset='', colorRange=(0.3, 0.55, 0.65), fontsize=8)
# Out:
# Start clustering reads...
# preprocessing input matrix...
# number of reads before filtering: 58
# number of reads kept: 39
# writing output to file:  ../figures/Figure3B_NUP170_auto_clusters_seed42_step20_na0.8_chrII:74300-75900.mtx
# For n_clusters = 2 The average silhouette_score is : 0.09144725574751746
# For n_clusters = 3 The average silhouette_score is : 0.07417501149610481
# For n_clusters = 4 The average silhouette_score is : 0.08769310959962012
# For n_clusters = 5 The average silhouette_score is : 0.05945451495751744
# For n_clusters = 6 The average silhouette_score is : 0.026489282225831905
# Clustering with number of clusters = 2
# Finished clustering reads!
# Figure size: 6 5
# plotting gene annotations...

# %% [markdown]
# ### PanelC ZDS2 gene

# %%
YML109W_pred  = '../data/resnetv1_chrXIII_all_prediction.tsv'
region = 'chrXIII:51100-52700'
pregion = 'chrXIII:51100-52700'
step = 20
chrom = region.split(':')[0]
qstart, qend = int(region.split(':')[1].split('-')[0]), int(region.split(':')[1].split('-')[1])
bins = np.arange(qstart, qend, step)

# %%
plotAllTrack(YML109W_pred, gtfFile, outpath = '../figures/', 
             step=20,
             prefix ='Figure3C_ZDS2_auto_clusters_seed42_step20_na0.8', bins = bins, region = region, seed=42,
             pregion = pregion, method = '', vlines = '', na_thred=0.2, ncluster='',
             savefig = True, trackHeight = 0.3, fig_size=(6,5), track_agg_adjust=0.1,
             xticks_space =100, subset='', colorRange=(0.3, 0.55, 0.65), fontsize=8)
# Out:
# Start clustering reads...
# preprocessing input matrix...
# number of reads before filtering: 40
# number of reads kept: 34
# writing output to file:  ../figures/Figure3C_ZDS2_auto_clusters_seed42_step20_na0.8_chrXIII:51100-52700.mtx
# For n_clusters = 2 The average silhouette_score is : 0.33661395485292533
# For n_clusters = 3 The average silhouette_score is : 0.06089364274584036
# For n_clusters = 4 The average silhouette_score is : 0.048506856675912105
# For n_clusters = 5 The average silhouette_score is : 0.06288742744065805
# For n_clusters = 6 The average silhouette_score is : 0.044731980707876574
# Clustering with number of clusters = 2
# Finished clustering reads!
# Figure size: 6 5
# plotting gene annotations...
